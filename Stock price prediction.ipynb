# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('NSE-Tata-Global-Beverages-Limited.csv')

# %%
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
data.shape
# Out:
# (1235, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
data.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
#check for null values 
data.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
#info about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
df= data.reset_index()['Open']
print(df)
# Out:
# 0       208.00
# 1       217.00
# 2       223.50
# 3       230.00
# 4       234.55
#          ...
# 1230    160.85
# 1231    161.15
# 1232    156.00
# 1233    155.70
# 1234    157.00
# Name: Open, Length: 1235, dtype: float64

# %%
#data visualization
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['Open'].plot(figsize=(16,6))
# Out:
# <Axes: >

# %%
# 7 day rolling mean
data.rolling(7).mean().head(15)
# Out:
# C:\Users\PALLABI\AppData\Local\Temp\ipykernel_24904\2079226427.py:2: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   data.rolling(7).mean().head(15)
#           Open        High         Low        Last       Close  \
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN
# 6   225.950000  230.500000  219.571429  223.935714  224.007143
# 7   230.521429  233.035714  223.235714  226.650000  226.735714
# 8   232.850000  235.628571  226.964286  230.364286  230.578571
# 9   234.285714  237.257143  229.050000  232.757143  232.735714
# 10  235.000000  237.185714  229.364286  233.800000  233.735714
# 11  235.200000  237.557143  231.135714  234.414286  234.307143
# 12  235.750000  238.028571  231.607143  234.700000  234.492857
# 13  235.550000  238.200000  231.485714  235.071429  234.971429
# 14  233.185714  237.728571  230.171429  234.928571  234.928571
#
#     Total Trade Quantity  Turnover (Lacs)
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# 5                    NaN              NaN
# 6           3.040937e+06      6822.042857
# 7           2.697903e+06      6134.295714
# 8           2.530739e+06      5862.415714
# 9           2.772843e+06      6460.095714
# 10          3.299518e+06      7692.855714
# 11          3.274848e+06      7652.388571
# 12          3.209831e+06      7509.724286
# 13          2.936693e+06      6879.075714
# 14          3.527693e+06      8241.347143

# %%
#visualization on rolling data
data['Open'].plot(figsize=(16,6))
data.rolling(window=30).mean()['Close'].plot()
# Out:
# C:\Users\PALLABI\AppData\Local\Temp\ipykernel_24904\849624634.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   data.rolling(window=30).mean()['Close'].plot()
# <Axes: >

# %%
data['Close: 30 Day Mean'] = data['Close'].rolling(window=30).mean()
data[['Close','Close: 30 Day Mean']].plot(figsize=(16,6))
# Out:
# <Axes: >

# %%
# Optional specify a minimum number of periods
data['Close'].expanding(min_periods=1).mean().plot(figsize=(16,6))
# Out:
# <Axes: >
